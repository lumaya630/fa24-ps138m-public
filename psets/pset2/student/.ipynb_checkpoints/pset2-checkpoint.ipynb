# %% [markdown]
# # Assignment 2: How Might Legalized Prostitution and Organ Opt-In Systems Impact Human Trafficking?

# %% [markdown]
# ### Substantive Objectives
# In this assignment, we will first review regression mechanics. Then we will be replicating a [study](https://www.sciencedirect.com/science/article/pii/S0305750X12001453)
# conducted by Cho, Dreher, and Neumayer in 2012 that investigates the relationship between legalized prostitution and human trafficking. The goal is for you to be able to run a simplified version of their regression and have your own critical interpretation of the output. **Make sure to read the study.**
#
# ### Coding Objectives
# 1) Running regressions using `lm()`
#
# ### General Tips
# Make sure you do not change the chunk type. You can change a chunk type by clicking on the dropdown menu next to the "forward" button or restart kernal button. Please post any questions on edX. A lot of working with coding is sometimes just going back to look for typos or being very precise with data transformations and the set of information put into the next box. Even one period or syntactical error can throw off the code! Make sure to use exact column names so that the code will pass all tests!
#
# ## Points
# This Assignment has 55 Points Total.

# %% [markdown]
# ## Setup
# The code chunk below loads the packages that we need.

# %%
# You *must* run this cell first. Do not change the contents of this cell.
library(testthat)
library(ottr)
library(IRdisplay)
library(tidyverse) %>% suppressMessages()
library(dplyr) %>% suppressMessages()

# %% [markdown]
# The code chunk below loads the dataset we will be using.

# %%
cho <- read.csv("cho_rep_clean.csv")

# %% [markdown]
# # Question 1: Regression Mechanics
# (16 points)

# %% [markdown]
# **a)(8 points) For the questions below, place the subquestion letter (e.g., "i)") by your answer.**
#
# ### <p style="color:#5F7BA4;">  Independent and Dependent Variables
# **i) (1 Point) A researcher runs a study on the relationship between anti-trafficking law enforcement funding and the number of identified sex trafficking cases, hypothesizing that greater law enforcement capacity to train officers and enforce laws leads to officers being better able to investigate and identify cases. What is the independent variable?**
#
# > A. Anti-trafficking law enforcement funding\
# B. Number of identified sex trafficking cases
#
# **ii) (1 Point) In question (i), what is the direction of the correlation?**
#
# > A. Positive correlation\
# B. Negative correlation
#
# **iii) (1 Point) A researcher runs a study on gender and human trafficking vulnerability, hypothesizing that being female will be associated with higher rates of trafficking reports. What is the dependent variable?**
#
# > A. Being female\
# B. Rate of trafficking reports
#
# **iv) (1 Point) What is also known as the "outcome variable"?**
#
# > A. Independent Variable\
# B. Dependent Variable
#
# **v) (1 Point) A researcher wants to know if greater demand for sexual services by Johns increases the price of these services. She models this with a linear regression. What is the "x" (independent) variable?**
# > A. Demand for Sexual Services\
# B. Price of Sexual Services
#
# **vi) (1 Point) What is the "y" (dependent) variable?**
# > A. Demand for Sexual Services\
# B. Price of Sexual Services
#
# **vii) (1 Point) A researcher wants to know if harsher penalities for sex trafficking leads to a lower demand of sexual services as a demand-side economic theory of trafficking. What is one way she might collect data on the "explanatory variable" for this topic?**
# > A. A survey experiment identifying the likelihood of Johns to buy sexual services\
# B. Identifying the prosecuation rates from court cases for offenders
#
# **viii) (1 Point) In the same scenario, the researcher proposes an alternative explanation that informational campaigns, rather than harsher penalities, may be responsible for the correlation or relationship observed. What is the confounding variable in this case?**
# > A. The number of public awareness informational campaigns\
# B. The strength of the legal system that allows for penalties for offenders

# %%
# YOUR SOLUTION GOES HERE
# Please write the answer in capital letters (E.g. i <- "A")
q1i <- NULL # YOUR CODE HERE
q1ii <- NULL # YOUR CODE HERE
q1iii <- NULL # YOUR CODE HERE
q1iv <- NULL # YOUR CODE HERE
q1v <- NULL # YOUR CODE HERE
q1vi <- NULL # YOUR CODE HERE
q1vii <- NULL # YOUR CODE HERE
q1viii <- NULL # YOUR CODE HERE

# %% [markdown]
# *Note: This test checks for formatting, not correctness*

# %%
. = ottr::check("tests/q1a.R")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# ### <p style="color:#5F7BA4;">  Estimates: $\alpha$, $\beta_1$
#
# **b) (2 points) The following is an equation for investigating the association between a country's poverty rate (measured in individuals per thousand) and the sex trafficking rate (also measured in individuals per thousand). Interpret the following equation in words. In your answer, make sure to explicitly explain the what $\alpha$ and $\beta_1$ represent.**
#
#    $$SexTraffickingRate_i = \alpha + \beta_1 PovertyRate_i + \varepsilon_i$$

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# **c) (2 point) We find $\alpha = 4$ and $\beta_1 = 0.5$. Based upon these coefficients, what is the predicted sex trafficking rate (per thousand individuals) in a country where the poverty rate is 20 per thousand. Store this value as an integer below.**

# %%
sextraffickingrate <- NULL # YOUR CODE HERE

# %% [markdown]
# *Note: This test checks for formatting, not correctness*

# %%
. = ottr::check("tests/q1c.R")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **d) (2 points) Can we claim that each additional unit increase in the poverty rate (in individuals) will increase the sex trafficking rate of a nation by 0.5 individuals? Why or why not?**

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# **e) (2 point) Think of one variable that is correlated with both the poverty rate and sex trafficking rate of a nation. Explicitly specify the direction of correlation (positive or negative) of your variable with the poverty rate, and the direction of correlation between your variable and the sex trafficking rate.**
#
# *The statistical term for such a variable is a "control variable".*

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Question 2: Understanding the Study
# (14 points)

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# Now we have our basic ingredients for understanding the methods the authors use in this study. Let's apply the regression concepts in understanding a prominent question in the field, does legalizing prostitution increase human trafficking?
#
# **a) (4 points) The authors develop their theory from two effects of legalizing prostitution on human trafficking: 1) the scale effect and 2) the substitution effect.**
#
# >(i) What is the scale effect?\
# (ii) What is the substitution effect?

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# **b) (2 points) For the questions below, put the corresponding letter of the correct answer in the respective roman numeral question.**
#
# When asking the question, does legalizing prostitution increase human trafficking...
#
# i) What is the independent variable?
#
# > A) human trafficking\
# B) legalized prostitution
#
# ii) What is the dependent variable?
#
# > A) human trafficking\
# B) legalized prostitution

# %%
# YOUR ANSWER GOES HERE  (e.g. i <- "A" or i <- "B")
q2b_i <- NULL # YOUR CODE HERE
q2b_ii <- NULL # YOUR CODE HERE

# %% [markdown]
# *Note: These tests check for formatting, not correctness*

# %%
. = ottr::check("tests/q2b.R")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **c) (2 points) Assign the corresponding letter answer to the corresponding roman numeral.**
#
# (i) **What do the authors use as their measure of human trafficking?**
#
# >A. An absolute number of new human trafficking victims\
# B. A absolute number of new sex trafficking victims\
# C. An index on the reported inflow of human trafficking\
# D. An index on the reported stock of human trafficking\
# E. An index on the reported inflow of sex trafficking
#
# (ii) **What is being compared?**
#
# >A. Trafficking in **countries where prostitution is legal** vs **countries where it is not**.\
# >B. Trafficking **before** vs **after** a country has legalized prostitution.

# %%
# YOUR ANSWER HERE. For example: i <- "A"
q2c_i <- NULL # YOUR CODE HERE
q2c_ii <- NULL # YOUR CODE HERE

# %% [markdown]
# *Note: These tests check for formatting, not correctness*

# %%
. = ottr::check("tests/q2c.R")

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# **e) (3 points) In estimating the relationship between legalizing prostitution and human trafficking inflows, what are three variables the authors control for? What is their reasoning for including them?**

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# **f) (1 point) What do the authors conclude?**
#
# A. Countries with legalized prostitution is associated with higher levels of human trafficking inflows. \
# B.  Legalizing prostitution increases levels of human trafficking inflows. \
# C. Countries with legalized prostitution is associated with lower levels of human trafficking inflows. \
# D. Legalizing prostitution decreases levels of human trafficking inflows.

# %%
f <- NULL # YOUR CODE HERE

# %% [markdown]
# *This test checks for formatting, not correctness.*

# %%
. = ottr::check("tests/q2f.R")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **g) (2 points) The authors are cautious about the interpretation. What do they say, and why are they so careful?**

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Question 3 Replicating the Regression
# (12 points)

# %% [markdown]
# The dataset used by Cho covers up to 150 countries using data on human trafficking from 1996-2003. The main variables are:
# * `htflowsunodc`: measures human trafficking flows
# * `prostitutionlaw`: indicates if prostitution is legal (0 = not legal, 1 = legal)

# %%
# NO ACTION NEEDED. 
# diplay first few rows
# the column loading the data is in the setup section, make sure to run it!
cho %>% head()

# %% [markdown]
# **a) (2 point) What is the number of countries with legalized prostitution?**
# > (i) Use the `filter()` function to subset to where `prostitutionlaw == 1`\
# > (ii) Use the `nrow()` function to get number of rows in the subset you created in (i)

# %%
# (i) filter to where prositution is legal
cho_legal <- NULL # YOUR CODE HERE

# display data, you can look through the country names if you are curious
cho_legal

# =====

# (ii) get the number of rows in the dataframe you just created
n_countries <- NULL # YOUR CODE HERE

# display data
n_countries

# %%
. = ottr::check("tests/q3a.R")

# %% [markdown]
# ### **b) (3 points) The equation Cho et al. is estimating is as follows:**
#
# $$y_i = \alpha + \beta_1 Prostitution + \beta_2X_i + s_i$$
#
# Where $X$ is the list of control variables. To run the regression, use the `lm()` function and the following specifications...
# * data: `cho`
# * IV:`prostitutionlaw`
# * DV:`htflowsunodc`
# * Controls: `prostitutionbrothel`, `ruleWB_m`, `pop_ln`, `gdp_pc_const_ppp_ln`,
#           `democracy`, `stockmigrants1990_ln`, `catholic2`, `reg_east_asia`,
#           `reg_west_europe`, `reg_latam`, `reg_mideast`, `reg_sasia`, `reg_ssa`
#
#
# Note: your numbers won't exactly match the numbers in the table, but it should be relatively similar. To replicate exactly their steps is a bit more complicated since the authors also use data imputations. For the purposes of this assignment, we are keeping it simple.

# %%
# YOUR ANSWER HERE
mod1 <- NULL # YOUR CODE HERE

# display
mod1 %>% summary()

# %%
. = ottr::check("tests/q3b.R")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **c) (2 points) In your regression output, the value in the `estimate`column for `prostitutionlaw` is equal to $\beta_1$ in the equation above. Your answer should return $\beta_1 = 0.54$. How would you interpret this estimate?**

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# **d) (3 points) What might be one alternative explanation for higher average reports of human trafficking in countries where prostituion is legal?**

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# **e) (2 points) How would you interpret the statement "correlation is not causation" in this context?**

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# ## Question 4
# 13 Points

# %% [markdown]
# The below data represents nations, average living donation rates ("Living"), and average deceased donation rates ("Deceased") if a nation's organ donation system is "Opt In" vs "Opt Out." In this exercise, we will have you look at the correlation of "Opt In" vs "Opt Out" organ donation policies, creating a dummy variable where "In" = 1 and "out" = 0, and correlate that with total transplant activity ("Total"). First, run the below cell to generate a dataframe. The data is measured in individuals per million.
#
# The data comes from this study: (https://www.sciencedirect.com/science/article/pii/S0085253819301851#sec1.2)

# %%
# RUN ME DO NOT CHANGE
# Opt in Policy Data

df <- data.frame(
  Country = c(
    "Australia","Austria","Belgium","Canada","Chilea",
    "Czech Republic","Denmark","Estonia","Finland","France",
    "Germany","Greece","Hungary","Iceland","Ireland",
    "Israel","Italy","Japan","Korea","Latvia",
    "Luxembourg","Mexico","Netherlands","New Zealand","Norway",
    "Poland","Portugal","Slovak Republic","Slovenia","Sweden",
    "Switzerland","Turkey","United Kingdom","United States"
  ),
  
  System = c(
    "In","Out","Out","In","Out",
    "Out","In","In","Out","Out",
    "In","Out","Out","In","In",
    "In","Out","In","In","Out",
    "Out","In","In","In","Out",
    "Out","Out","Out","Out","Out",
    "In","In","In","In"
  ),
  
  Deceased = c(
    20.6,24.8,30.7,20.0,7.4,
    25.1,17.4,16.8,24.6,28.6,
    10.4,4.6,18.7,26.9,16.2,
    10.2,24.9,0.8,11.4,15.4,
    5.1,3.6,14.7,13.0,20.9,
    14.2,32.6,13.2,20.2,20.3,
    13.1,7.0,21.2,30.7
  ),
  
  Living = c(
    10.9,7.9,9.6,14.9,5.3,
    4.4,19.0,3.1,4.0,8.9,
    7.9,4.4,3.5,14.9,10.5,
    27.6,4.8,14.6,42.4,5.1,
    NA,16.4,33.9,18.1,8.9,
    2.0,6.3,3.5,1.0,14.4,
    15.5,45.1,15.9,18.4
  ),
  
  Total = c(
    72.6,89.3,90.0,79.6,24.5,
    75.4,67.5,43.5,72.2,90.8,
    45.0,13.5,51.8,14.9,58.8,
    62.5,63.6,29.9,79.3,31.8,
    NA,24.7,75.4,55.7,78.2,
    42.6,82.2,36.7,52.4,80.8,
    60.4,60.9,73.7,106.1
  )
)

# display
df

# %% [markdown]
# **a) (1 Point) Create a Dummy Variable**
# In this step, we will have you code the Opt In vs. Opt Out systems of organ donation as a dummy variable, where "1" denotes "Opt-In" an "0" denotes "Opt-Out". A dummy variable is a binary representation for a variable. You will need to use an ifelse function. See the below text to run the code. Note that the 1 indicates that the number 1 should replace that text, and the 0 indicates that all other values will take 0.
#
# `ifelse(data$column_name == "variable character/categorical text you are selecting for", 1, 0)`

# %%
df$OptIn_System_Dummy <- NULL # YOUR CODE HERE

# %%
. = ottr::check("tests/q4a.R")

# %% [markdown]
# **b) (2 Points) Average Living and Deceased Rates**
# Now we will find the average Living and Deceased Transplant Rates for countries with Opt-In and Opt-Out policies. We will need to use a `dplyr` function. Recall in previous assignments we learned how to take the mean. We want to take the mean of two different variables. Use the "System" variable and not the dummy variable just yet -- we will use that for the regression later on.
#
#     dataframename %>%
#         group_by(variablecategory) %>%
#           summarise(
#             SecondaryComparisonColumn = mean(SecondaryComparisonColumn, na.rm = TRUE),
#             SecondaryComparisonColumn2 = mean(SecondaryComparisonColumn2, na.rm = TRUE)
#           )
#
# The column names in your `df_summary` should be "System", "Living", and "Deceased".

# %%
df_summary <- df %>%
  # YOUR CODE HERE

# Display
df_summary

# %%
. = ottr::check("tests/q4b.R")

# %% [markdown]
# **c) (2 Points) Correlation: System Type vs Total Transplant Activity**
#
# Now we want to correlate system type with total transplant activity. Let's now use our dummy variable to run a simple correlation. Use the template below.
#
# `cor(dataframename$newdummyvariable, dataframename$relevantOutcomeVariable, use = "complete.obs")`

# %%
correlation <- NULL # YOUR CODE HERE

# %%
. = ottr::check("tests/q4c.R")

# %% [markdown]
# **d) (2 Points) Regression**
# Now we will create a regression equation.
# Use the regression equation we have learned in the following format.
# `lm(OutcomeVariable ~ InputVariable, data = dataframename)`

# %%
model <- NULL # YOUR CODE HERE
summary(model)

# %%
. = ottr::check("tests/q4d.R")

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# **e) Interpret the above data.**
#
# Remember, we are working with a dummy variable, in which the input can be either "1" or "0." In this case, our alpha and beta variables both have meaning that is important to interpretation, because we are forcing one variable to be represented by a y-intercept/alpha co-efficient.
#
#  **i. (2 Points)** What is the intercept co-efficient (alpha)? What does it mean? Interpret it in context.
#
# **ii. (2 Points)** What is the explanatory co-efficient (beta)? What does it mean? Interpret it in context.
#
# **iii. (2 Points)** Are the findings significant?

# %% [markdown]
# _Type your answer here, replacing this text._

# %% [markdown]
# <!-- END QUESTION -->
#
# # Submitting Your Notebook (please read carefully!)
#
# To submit your notebook...
#
# ### 1. Click `File` $\rightarrow$ `Save Notebook`.
#
# ### 2. Wait 5 seconds.
#
# ### 3. Select the cell below and hit run.tion:**

# %%
ottr::export("pset2.ipynb")

# %% [markdown]
# After you hit "Run" on the cell above, click the download link. A .zip file should download to your computer.
#
# (If you make changes to your notebook, you'll need to hit save and then run the cell above again before you submit to get a new version of it.)
#
# ### 4. Submit the .zip file you just downloaded <a href="https://www.gradescope.com/" target="_blank">on Gradescope</a>.
#
# Notes:
#
# - **This does not seem to work on Chrome for iPad or iPhone.** If you're using an iPad or iPhone, you need to download the file using **Safari**.
# - If your web browser automatically unzips the .zip file (so you see a folder instead of a .zip file), you can just upload the .ipynb file that is inside the folder.
# - If this method is not working for you, try this: hit `File`, then `Download as`, then `Notebook (.ipynb)` and submit that.
